# %% [markdown]
# # Section 1: Introduction
#
# This notebook has been designed with the intent of analyzing multiple MF schemes and develop a robust portfolio.

# %%
# importing necessary libraries
import os
import pandas as pd
from dotenv import load_dotenv
import matplotlib.pyplot as plt

# initializing environment variables
load_dotenv()
amfi_nav_eng_data = os.getenv('amfi_nav_eng_data')

# %% [markdown]
# ## 1.1. Exploratory Data Analysis
#
# This section focuses on initial data load and performing an EDA on the raw dataset.

# %%
df_amfi_nav_eng_data = pd.read_csv(amfi_nav_eng_data)
print(f'Raw dataset:\n{df_amfi_nav_eng_data.head(10)}')
print(f'Dataset datatypes:\n{df_amfi_nav_eng_data.dtypes}')
# Out:
# Raw dataset:
#        SNo.  schemeCode_NAV tradingsymbol    isinGrowth isinDivReinvestment  \
# 0  10483342          100033  INF209K01165  INF209K01165                 NaN
# 1  10479204          100033  INF209K01165  INF209K01165                 NaN
# 2  10481196          100033  INF209K01165  INF209K01165                 NaN
# 3  10480087          100033  INF209K01165  INF209K01165                 NaN
# 4  10486438          100033  INF209K01165  INF209K01165                 NaN
# 5  10485180          100033  INF209K01165  INF209K01165                 NaN
# 6  10483462          100033  INF209K01165  INF209K01165                 NaN
# 7  10480192          100033  INF209K01165  INF209K01165                 NaN
# 8  10474280          100033  INF209K01165  INF209K01165                 NaN
# 9  10476310          100033  INF209K01165  INF209K01165                 NaN
#
#                          amc                                          name  \
# ...
